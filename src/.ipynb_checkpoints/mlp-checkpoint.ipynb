# %% [markdown]
# # Install the dependencies

# %% [markdown]
# # Import the dependencies

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Load the dataset digits

# %%
digits = fetch_openml('mnist_784')
# Out:
# C:\Users\mpps\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %% [markdown]
# # Divide the data

# %%
### divide to get train and test data with train_test_split() ###
X_train, X_test, y_train, y_test = train_test_split((digits.data/255), digits.target, test_size=0.3)

# %% [markdown]
# # Create and train the model

# %% [markdown]
# ## Test 1
# - One hidden layer
# - 100 neurons
# - 60 epochs
# - Learning rate = 0.1
# - Batch size = 10
# - No regularization
# - No dropout

# %%
### first create the MLP model with the MLP classifier from skit-learn

mlp = MLPClassifier(
    hidden_layer_sizes=(100,),  # here is the number of nodes and hidden layers
    max_iter=60,                # number of trainning steps
    solver='sgd',               # optimization algorithm, stochastic gradient descent
    verbose=10,                 # quantity of trainning output
    learning_rate_init=0.1,     # initial learning_rate, updates network weights
    batch_size=10,              # batch size of trainning
    random_state=1              # random state to reproduct the tests
)

# %%
mlp.fit(X_train, y_train)  # trainning the data
# Out:
# Iteration 1, loss = 0.97816276
# Iteration 2, loss = 1.10988413
# Iteration 3, loss = 1.15765986
# Iteration 4, loss = 1.17165461
# Iteration 5, loss = 1.12094379
# Iteration 6, loss = 1.22004001
# Iteration 7, loss = 1.25257916
# Iteration 8, loss = 1.20382698
# Iteration 9, loss = 1.36010887
# Iteration 10, loss = 1.36762200
# Iteration 11, loss = 1.30849299
# Iteration 12, loss = 1.42877998
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(batch_size=10, learning_rate_init=0.1, max_iter=60,
#               random_state=1, solver='sgd', verbose=10)

# %%
### score accuracy, precision and recall
predictions = mlp.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Acurácia do MLP: {:.2f}%".format(accuracy * 100))

precision = precision_score(y_test, predictions, average='weighted')
print("Precisão do modelo: {:.2f}%".format(precision * 100))

recall = recall_score(y_test, predictions, average='weighted')
print("Recall do modelo: {:.2f}%".format(recall * 100))
# Out:
# Acurácia do MLP: 51.19%
# Precisão do modelo: 70.81%
# Recall do modelo: 51.19%

# %%
### plot the losses
losses = mlp.loss_curve_

plt.plot(losses)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.title("loss behavior per epoch")
# Out:
# Text(0.5, 1.0, 'loss behavior per epoch')

# %%
cm = confusion_matrix(y_test, predictions)
row_sums = cm.sum(axis=1, keepdims=True)
percentage_matrix = np.round((cm / row_sums) * 100, decimals=2)
sns.set_theme(font_scale=.9)
heat_map = sns.heatmap(percentage_matrix, annot=True, cmap='Blues', fmt='g', )
plt.show()

# %% [markdown]
# In this heat map it's possible to see the accuracy for each class

# %% [markdown]
# ## Test 2
# - Two hidden layer
# - 100 neurons
# - 60 epochs
# - Learning rate = 0.1
# - Bacth size 10
# - No regularization
# - No droupout

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100,2),
    max_iter=60,               
    solver='sgd',              
    verbose=10,                
    learning_rate_init=0.1,    
    batch_size=10,
    random_state=1
)

# %%
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 2.30300991
# Iteration 2, loss = 2.32774218
# Iteration 3, loss = 2.32739774
# Iteration 4, loss = 2.32665038
# Iteration 5, loss = 2.32522964
# Iteration 6, loss = 2.32496765
# Iteration 7, loss = 2.32518839
# Iteration 8, loss = 2.32450701
# Iteration 9, loss = 2.32524611
# Iteration 10, loss = 2.32434564
# Iteration 11, loss = 2.32376016
# Iteration 12, loss = 2.32407877
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(batch_size=10, hidden_layer_sizes=(100, 2),
#               learning_rate_init=0.1, max_iter=60, random_state=1, solver='sgd',
#               verbose=10)

# %%
### score accuracy, precision and recall
predictions = mlp.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Acurácia do MLP: {:.2f}%".format(accuracy * 100))

precision = precision_score(y_test, predictions, average='weighted')
print("Precisão do modelo: {:.2f}%".format(precision * 100))

recall = recall_score(y_test, predictions, average='weighted')
print("Recall do modelo: {:.2f}%".format(recall * 100))
# Out:
# Acurácia do MLP: 11.25%
# Precisão do modelo: 1.27%
# Recall do modelo: 11.25%
# C:\Users\mpps\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
### plot the losses
losses = mlp.loss_curve_

plt.plot(losses)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.title("loss behavior per epoch")
# Out:
# Text(0.5, 1.0, 'loss behavior per epoch')

# %%
cm = confusion_matrix(y_test, predictions)
row_sums = cm.sum(axis=1, keepdims=True)
percentage_matrix = np.round((cm / row_sums) * 100, decimals=2)
plt.rcdefaults()
sns.set_theme(font_scale=.9)
heat_map = sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel("predictions")
plt.ylabel("data test")
plt.title("classes accuracy")
plt.show()
plt.rcdefaults()

# %% [markdown]
# ## teste 3
# - One hidden layer
# - 100 neurons
# - 60 epochs
# - Learning rate = 1.0
# - Batch size = 10
# - No Regularization
# - No dropout

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100,),
    max_iter=60,              
    solver='sgd',             
    verbose=10,               
    learning_rate_init=1.0,   
    batch_size=10,
    random_state=1,
)

# %%
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 3.21421614
# Iteration 2, loss = 2.74980729
# Iteration 3, loss = 2.55960829
# Iteration 4, loss = 2.49182694
# Iteration 5, loss = 2.46493912
# Iteration 6, loss = 2.46028346
# Iteration 7, loss = 2.45262626
# Iteration 8, loss = 2.45652155
# Iteration 9, loss = 2.45301919
# Iteration 10, loss = 2.45414051
# Iteration 11, loss = 2.45050831
# Iteration 12, loss = 2.45530180
# Iteration 13, loss = 2.45132352
# Iteration 14, loss = 2.45307496
# Iteration 15, loss = 2.45208712
# Iteration 16, loss = 2.45193580
# Iteration 17, loss = 2.45306931
# Iteration 18, loss = 2.45287222
# Iteration 19, loss = 2.45424422
# Iteration 20, loss = 2.44783269
# Iteration 21, loss = 2.45517213
# Iteration 22, loss = 2.45391133
# Iteration 23, loss = 2.44896976
# Iteration 24, loss = 2.45582424
# Iteration 25, loss = 2.45154309
# Iteration 26, loss = 2.45243480
# Iteration 27, loss = 2.45106656
# Iteration 28, loss = 2.44829188
# Iteration 29, loss = 2.45216183
# Iteration 30, loss = 2.45433339
# Iteration 31, loss = 2.45142173
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(batch_size=10, learning_rate_init=1.0, max_iter=60,
#               random_state=1, solver='sgd', verbose=10)

# %%
### score accuracy, precision and recall
predictions = mlp.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Acurácia do MLP: {:.2f}%".format(accuracy * 100))

precision = precision_score(y_test, predictions, average='weighted')
print("Precisão do modelo: {:.2f}%".format(precision * 100))

recall = recall_score(y_test, predictions, average='weighted')
print("Recall do modelo: {:.2f}%".format(recall * 100))
# Out:
# Acurácia do MLP: 9.62%
# Precisão do modelo: 0.93%
# Recall do modelo: 9.62%
# C:\Users\mpps\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
### plot the losses
losses = mlp.loss_curve_

plt.plot(losses)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.title("loss behavior per epoch")
plt.rcdefaults()
plt.show()

# %%
cm = confusion_matrix(y_test, predictions)
row_sums = cm.sum(axis=1, keepdims=True)
percentage_matrix = np.round((cm / row_sums) * 100, decimals=2)

sns.set_theme(font_scale=.9)
heat_map = sns.heatmap(percentage_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel("predictions")
plt.ylabel("data test")
plt.title("classes accuracy")
plt.show()
plt.rcdefaults()

# %% [markdown]
# ## teste 4
# - One hidden layer
# - 100 neurons
# - 60 epochs
# - Learning rate = 0.1
# - Batch size = 100
# - No regularization

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100,),
    max_iter=60,              
    solver='sgd',              
    verbose=10,                
    learning_rate_init=0.1,    
    batch_size=100,
    random_state=1
)

# %%
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.25443786
# Iteration 2, loss = 0.11080399
# Iteration 3, loss = 0.08078756
# Iteration 4, loss = 0.06420249
# Iteration 5, loss = 0.05148398
# Iteration 6, loss = 0.04230245
# Iteration 7, loss = 0.03495181
# Iteration 8, loss = 0.02796765
# Iteration 9, loss = 0.02186957
# Iteration 10, loss = 0.01816757
# Iteration 11, loss = 0.01499025
# Iteration 12, loss = 0.01190484
# Iteration 13, loss = 0.00888330
# Iteration 14, loss = 0.00659212
# Iteration 15, loss = 0.00426747
# Iteration 16, loss = 0.00285078
# Iteration 17, loss = 0.00208612
# Iteration 18, loss = 0.00171611
# Iteration 19, loss = 0.00156064
# Iteration 20, loss = 0.00147562
# Iteration 21, loss = 0.00143078
# Iteration 22, loss = 0.00134500
# Iteration 23, loss = 0.00131160
# Iteration 24, loss = 0.00127556
# Iteration 25, loss = 0.00123299
# Iteration 26, loss = 0.00121235
# Iteration 27, loss = 0.00119470
# Iteration 28, loss = 0.00116885
# Iteration 29, loss = 0.00115169
# Iteration 30, loss = 0.00113323
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(batch_size=100, learning_rate_init=0.1, max_iter=60,
#               random_state=1, solver='sgd', verbose=10)

# %%
### score accuracy, precision and recall
predictions = mlp.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Acurácia do MLP: {:.2f}%".format(accuracy * 100))

precision = precision_score(y_test, predictions, average='weighted')
print("Precisão do modelo: {:.2f}%".format(precision * 100))

recall = recall_score(y_test, predictions, average='weighted')
print("Recall do modelo: {:.2f}%".format(recall * 100))
# Out:
# Acurácia do MLP: 97.83%
# Precisão do modelo: 97.83%
# Recall do modelo: 97.83%

# %%
### plot the losses
losses = mlp.loss_curve_

plt.plot(losses)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.title("loss behavior per epoch")
plt.rcdefaults()
plt.show()

# %%
cm = confusion_matrix(y_test, predictions)
row_sums = cm.sum(axis=1, keepdims=True)
percentage_matrix = np.round((cm / row_sums) * 100, decimals=1)

sns.set_theme(font_scale=1.2)
heat_map = sns.heatmap(percentage_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel("predictions")
plt.ylabel("data test")
plt.title("classes accuracy")
plt.show()
plt.rcdefaults()

# %% [markdown]
# ## teste 5
# - One hidden layer
# - 100 neurons
# - 60 epochs
# - Learning rate = 0.1
# - Batch size = 100
# - Regularization = 0.0001

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100,),
    max_iter=60,              
    solver='sgd',              
    verbose=10,                
    learning_rate_init=0.1,    
    batch_size=100,
    alpha=0.0001,
    random_state=1
)

# %%
mlp.fit(X_train, y_train)

### score accuracy, precision and recall
predictions = mlp.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Acurácia do MLP: {:.2f}%".format(accuracy * 100))

precision = precision_score(y_test, predictions, average='weighted')
print("Precisão do modelo: {:.2f}%".format(precision * 100))

recall = recall_score(y_test, predictions, average='weighted')
print("Recall do modelo: {:.2f}%".format(recall * 100))
# Out:
# Iteration 1, loss = 0.25443786
# Iteration 2, loss = 0.11080399
# Iteration 3, loss = 0.08078756
# Iteration 4, loss = 0.06420249
# Iteration 5, loss = 0.05148398
# Iteration 6, loss = 0.04230245
# Iteration 7, loss = 0.03495181
# Iteration 8, loss = 0.02796765
# Iteration 9, loss = 0.02186957
# Iteration 10, loss = 0.01816757
# Iteration 11, loss = 0.01499025
# Iteration 12, loss = 0.01190484
# Iteration 13, loss = 0.00888330
# Iteration 14, loss = 0.00659212
# Iteration 15, loss = 0.00426747
# Iteration 16, loss = 0.00285078
# Iteration 17, loss = 0.00208612
# Iteration 18, loss = 0.00171611
# Iteration 19, loss = 0.00156064
# Iteration 20, loss = 0.00147562
# Iteration 21, loss = 0.00143078
# Iteration 22, loss = 0.00134500
# Iteration 23, loss = 0.00131160
# Iteration 24, loss = 0.00127556
# Iteration 25, loss = 0.00123299
# Iteration 26, loss = 0.00121235
# Iteration 27, loss = 0.00119470
# Iteration 28, loss = 0.00116885
# Iteration 29, loss = 0.00115169
# Iteration 30, loss = 0.00113323
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Acurácia do MLP: 97.83%
# Precisão do modelo: 97.83%
# Recall do modelo: 97.83%

# %%
### plot the losses
losses = mlp.loss_curve_

plt.plot(losses)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.title("loss behavior per epoch")
plt.show()
plt.rcdefaults()

# %%
cm = confusion_matrix(y_test, predictions)
row_sums = cm.sum(axis=1, keepdims=True)
percentage_matrix = np.round((cm / row_sums) * 100, decimals=1)

sns.set_theme(font_scale=1.2)
heat_map = sns.heatmap(percentage_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel("predictions")
plt.ylabel("data test")
plt.title("classes accuracy")
plt.show()
plt.rcdefaults()

# %% [markdown]
# ## teste 6
# - One hidden layer
# - 100 neurons
# - 60 epochs
# - Learning rate = 0.1
# - Batch size = 100
# - Regularization = 0.0001
# - Dropout = 0.2

# %%
# code source: https://datascience.stackexchange.com/questions/117082/how-can-i-implement-dropout-in-scikit-learn

# Creating a custom MLPDropout classifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network._stochastic_optimizers import AdamOptimizer, SGDOptimizer
from sklearn.neural_network._base import ACTIVATIONS, DERIVATIVES, LOSS_FUNCTIONS
from sklearn.utils import shuffle, gen_batches, check_random_state, _safe_indexing
from sklearn.utils.extmath import safe_sparse_dot
import warnings
from sklearn.exceptions import ConvergenceWarning

class MLPDropout(MLPClassifier):
    
    def __init__(
        self,
        hidden_layer_sizes=(100,),
        activation="relu",
        *,
        solver="adam",
        alpha=0.0001,
        batch_size="auto",
        learning_rate="constant",
        learning_rate_init=0.001,
        power_t=0.5,
        max_iter=200,
        shuffle=True,
        random_state=None,
        tol=1e-4,
        verbose=False,
        warm_start=False,
        momentum=0.9,
        nesterovs_momentum=True,
        early_stopping=False,
        validation_fraction=0.1,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=1e-8,
        n_iter_no_change=10,
        max_fun=15000,
        dropout = None,
    ):
        '''
        Additional Parameters:
        ----------
        dropout : float in range (0, 1), default=None
            Dropout parameter for the model, defines the percentage of nodes
            to remove at each layer.
            
        '''
        self.dropout = dropout
        super().__init__(
            hidden_layer_sizes=hidden_layer_sizes,
            activation=activation,
            solver=solver,
            alpha=alpha,
            batch_size=batch_size,
            learning_rate=learning_rate,
            learning_rate_init=learning_rate_init,
            power_t=power_t,
            max_iter=max_iter,
            shuffle=shuffle,
            random_state=random_state,
            tol=tol,
            verbose=verbose,
            warm_start=warm_start,
            momentum=momentum,
            nesterovs_momentum=nesterovs_momentum,
            early_stopping=early_stopping,
            validation_fraction=validation_fraction,
            beta_1=beta_1,
            beta_2=beta_2,
            epsilon=epsilon,
            n_iter_no_change=n_iter_no_change,
            max_fun=max_fun,
        )
    
    def _fit_stochastic(
        self,
        X,
        y,
        activations,
        deltas,
        coef_grads,
        intercept_grads,
        layer_units,
        incremental,
    ):
        params = self.coefs_ + self.intercepts_
        if not incremental or not hasattr(self, "_optimizer"):
            if self.solver == "sgd":
                self._optimizer = SGDOptimizer(
                    params,
                    self.learning_rate_init,
                    self.learning_rate,
                    self.momentum,
                    self.nesterovs_momentum,
                    self.power_t,
                )
            elif self.solver == "adam":
                self._optimizer = AdamOptimizer(
                    params,
                    self.learning_rate_init,
                    self.beta_1,
                    self.beta_2,
                    self.epsilon,
                )

        # early_stopping in partial_fit doesn't make sense
        early_stopping = self.early_stopping and not incremental
        if early_stopping:
            # don't stratify in multilabel classification
            should_stratify = is_classifier(self) and self.n_outputs_ == 1
            stratify = y if should_stratify else None
            X, X_val, y, y_val = train_test_split(
                X,
                y,
                random_state=self._random_state,
                test_size=self.validation_fraction,
                stratify=stratify,
            )
            if is_classifier(self):
                y_val = self._label_binarizer.inverse_transform(y_val)
        else:
            X_val = None
            y_val = None

        n_samples = X.shape[0]
        sample_idx = np.arange(n_samples, dtype=int)

        if self.batch_size == "auto":
            batch_size = min(200, n_samples)
        else:
            if self.batch_size < 1 or self.batch_size > n_samples:
                warnings.warn(
                    "Got `batch_size` less than 1 or larger than "
                    "sample size. It is going to be clipped"
                )
            batch_size = np.clip(self.batch_size, 1, n_samples)

        try:
            for it in range(self.max_iter):
                if self.shuffle:
                    # Only shuffle the sample indices instead of X and y to
                    # reduce the memory footprint. These indices will be used
                    # to slice the X and y.
                    sample_idx = shuffle(sample_idx, random_state=self._random_state)

                accumulated_loss = 0.0
                for batch_slice in gen_batches(n_samples, batch_size):
                    if self.shuffle:
                        X_batch = _safe_indexing(X, sample_idx[batch_slice])
                        y_batch = y[sample_idx[batch_slice]]
                    else:
                        X_batch = X[batch_slice]
                        y_batch = y[batch_slice]
                    
                    activations[0] = X_batch
                    # (DROPOUT ADDITION) layer_units passed forward to help build dropout mask.
                    batch_loss, coef_grads, intercept_grads = self._backprop(
                        X_batch,
                        y_batch,
                        activations,
                        layer_units,
                        deltas,
                        coef_grads,
                        intercept_grads,
                    )
                    accumulated_loss += batch_loss * (
                        batch_slice.stop - batch_slice.start
                    )

                    # update weights
                    grads = coef_grads + intercept_grads
                    self._optimizer.update_params(params, grads)

                self.n_iter_ += 1
                self.loss_ = accumulated_loss / X.shape[0]

                self.t_ += n_samples
                self.loss_curve_.append(self.loss_)
                if self.verbose:
                    print("Iteration %d, loss = %.8f" % (self.n_iter_, self.loss_))

                # update no_improvement_count based on training loss or
                # validation score according to early_stopping
                self._update_no_improvement_count(early_stopping, X_val, y_val)

                # for learning rate that needs to be updated at iteration end
                self._optimizer.iteration_ends(self.t_)

                if self._no_improvement_count > self.n_iter_no_change:
                    # not better than last `n_iter_no_change` iterations by tol
                    # stop or decrease learning rate
                    if early_stopping:
                        msg = (
                            "Validation score did not improve more than "
                            "tol=%f for %d consecutive epochs."
                            % (self.tol, self.n_iter_no_change)
                        )
                    else:
                        msg = (
                            "Training loss did not improve more than tol=%f"
                            " for %d consecutive epochs."
                            % (self.tol, self.n_iter_no_change)
                        )

                    is_stopping = self._optimizer.trigger_stopping(msg, self.verbose)
                    if is_stopping:
                        break
                    else:
                        self._no_improvement_count = 0

                if incremental:
                    break

                if self.n_iter_ == self.max_iter:
                    warnings.warn(
                        "Stochastic Optimizer: Maximum iterations (%d) "
                        "reached and the optimization hasn't converged yet."
                        % self.max_iter,
                        ConvergenceWarning,
                    )
        except KeyboardInterrupt:
            warnings.warn("Training interrupted by user.")

        if early_stopping:
            # restore best weights
            self.coefs_ = self._best_coefs
            self.intercepts_ = self._best_intercepts
    
    def _backprop(self, X, y, activations, layer_units, deltas, coef_grads, intercept_grads):
        """Compute the MLP loss function and its corresponding derivatives
        with respect to each parameter: weights and bias vectors.

        Parameters
        ----------
        X : {array-like, sparse matrix} of shape (n_samples, n_features)
            The input data.

        y : ndarray of shape (n_samples,)
            The target values.

        activations : list, length = n_layers - 1
            The ith element of the list holds the values of the ith layer.
             
        layer_units (DROPOUT ADDITION) : list, length = n_layers
            The layer units of the neural net, this is the shape of the
            Neural Net model. This is used to build the dropout mask.

        deltas : list, length = n_layers - 1
            The ith element of the list holds the difference between the
            activations of the i + 1 layer and the backpropagated error.
            More specifically, deltas are gradients of loss with respect to z
            in each layer, where z = wx + b is the value of a particular layer
            before passing through the activation function

        coef_grads : list, length = n_layers - 1
            The ith element contains the amount of change used to update the
            coefficient parameters of the ith layer in an iteration.

        intercept_grads : list, length = n_layers - 1
            The ith element contains the amount of change used to update the
            intercept parameters of the ith layer in an iteration.

        Returns
        -------
        loss : float
        coef_grads : list, length = n_layers - 1
        intercept_grads : list, length = n_layers - 1
        """
        n_samples = X.shape[0]
        dropout_masks = None
        
        # Create the Dropout Mask (DROPOUT ADDITION)
        if self.dropout != None:
            if 0 < self.dropout < 1:
                keep_probability = 1 - self.dropout
                dropout_masks = [np.ones(layer_units[0])]
                
                # Create hidden Layer Dropout Masks
                for units in layer_units[1:-1]:
                    # Create inverted Dropout Mask, check for random_state
                    if self.random_state != None:
                        layer_mask = (self._random_state.random(units) < keep_probability).astype(int) / keep_probability
                    else:
                        layer_mask = (np.random.rand(units) < keep_probability).astype(int) / keep_probability
                    dropout_masks.append(layer_mask)
            else:
                raise ValueError('Dropout must be between zero and one. If Dropout=X then, 0 < X < 1.')
        
        # Forward propagate
        # Added dropout_makss to _forward_pass call (DROPOUT ADDITION)
        activations = self._forward_pass(activations, dropout_masks)
        
        # Get loss
        loss_func_name = self.loss
        if loss_func_name == "log_loss" and self.out_activation_ == "logistic":
            loss_func_name = "binary_log_loss"
        loss = LOSS_FUNCTIONS[loss_func_name](y, activations[-1])
        # Add L2 regularization term to loss
        values = 0
        for s in self.coefs_:
            s = s.ravel()
            values += np.dot(s, s)
        loss += (0.5 * self.alpha) * values / n_samples

        # Backward propagate
        last = self.n_layers_ - 2

        # The calculation of delta[last] here works with following
        # combinations of output activation and loss function:
        # sigmoid and binary cross entropy, softmax and categorical cross
        # entropy, and identity with squared loss
        deltas[last] = activations[-1] - y
        
        # Compute gradient for the last layer
        self._compute_loss_grad(
            last, n_samples, activations, deltas, coef_grads, intercept_grads
        )

        inplace_derivative = DERIVATIVES[self.activation]
        # Iterate over the hidden layers
        for i in range(self.n_layers_ - 2, 0, -1):
            deltas[i - 1] = safe_sparse_dot(deltas[i], self.coefs_[i].T)
            inplace_derivative(activations[i], deltas[i - 1])
            
            self._compute_loss_grad(
                i - 1, n_samples, activations, deltas, coef_grads, intercept_grads
            )
        
        # Apply Dropout Masks to the Parameter Gradients (DROPOUT ADDITION)
        if dropout_masks != None:
            for layer in range(len(coef_grads)-1):
                mask = (~(dropout_masks[layer+1] == 0)).astype(int)
                coef_grads[layer] = coef_grads[layer] * mask[None, :]
                coef_grads[layer+1] = (coef_grads[layer+1] * mask.reshape(-1, 1))
                intercept_grads[layer] = intercept_grads[layer] * mask
        
        return loss, coef_grads, intercept_grads
    
    def _forward_pass(self, activations, dropout_masks=None):
        """Perform a forward pass on the network by computing the values
        of the neurons in the hidden layers and the output layer.

        Parameters
        ----------
        activations : list, length = n_layers - 1
            The ith element of the list holds the values of the ith layer.
        dropout_mask : list, length = n_layers - 1
            The ith element of the list holds the dropout mask for the ith
            layer.
        """
        hidden_activation = ACTIVATIONS[self.activation]
        # Iterate over the hidden layers
        for i in range(self.n_layers_ - 1):
            activations[i + 1] = safe_sparse_dot(activations[i], self.coefs_[i])
            activations[i + 1] += self.intercepts_[i]
            
            # For the hidden layers
            if (i + 1) != (self.n_layers_ - 1):
                hidden_activation(activations[i + 1])
            
            # Apply Dropout Mask (DROPOUT ADDITION)
            if (i + 1) != (self.n_layers_ - 1) and dropout_masks != None:
                check1 = activations[i].copy()
                activations[i+1] = activations[i+1] * dropout_masks[i+1][None, :]

        # For the last layer
        output_activation = ACTIVATIONS[self.out_activation_]
        output_activation(activations[i + 1])
        return activations

# %%
mlp = MLPDropout(
    hidden_layer_sizes=(100,),
    max_iter=60,              
    solver='sgd',              
    verbose=10,                
    learning_rate_init=0.1,    
    batch_size=100,
    alpha=0.0001,
    dropout=0.2,
    random_state=1
)

# %%
mlp.fit(X_train, y_train)

### score accuracy, precision and recall
predictions = mlp.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Acurácia do MLP: {:.2f}%".format(accuracy * 100))

precision = precision_score(y_test, predictions, average='weighted')
print("Precisão do modelo: {:.2f}%".format(precision * 100))

recall = recall_score(y_test, predictions, average='weighted')
print("Recall do modelo: {:.2f}%".format(recall * 100))
# Out:
# Iteration 1, loss = 0.33620323
# Iteration 2, loss = 0.16677334
# Iteration 3, loss = 0.13365973
# Iteration 4, loss = 0.11917722
# Iteration 5, loss = 0.10571299
# Iteration 6, loss = 0.09382705
# Iteration 7, loss = 0.08698781
# Iteration 8, loss = 0.07953606
# Iteration 9, loss = 0.07935118
# Iteration 10, loss = 0.07337657
# Iteration 11, loss = 0.07100645
# Iteration 12, loss = 0.06293969
# Iteration 13, loss = 0.05852562
# Iteration 14, loss = 0.05708385
# Iteration 15, loss = 0.06034198
# Iteration 16, loss = 0.05249490
# Iteration 17, loss = 0.05101860
# Iteration 18, loss = 0.04880479
# Iteration 19, loss = 0.05095660
# Iteration 20, loss = 0.04542459
# Iteration 21, loss = 0.04578552
# Iteration 22, loss = 0.04258873
# Iteration 23, loss = 0.04193890
# Iteration 24, loss = 0.04232487
# Iteration 25, loss = 0.04148144
# Iteration 26, loss = 0.04072216
# Iteration 27, loss = 0.03993963
# Iteration 28, loss = 0.04004666
# Iteration 29, loss = 0.03696131
# Iteration 30, loss = 0.03620533
# Iteration 31, loss = 0.03655188
# Iteration 32, loss = 0.03384426
# Iteration 33, loss = 0.03699295
# Iteration 34, loss = 0.03492812
# Iteration 35, loss = 0.03391700
# Iteration 36, loss = 0.03337285
# Iteration 37, loss = 0.03421797
# Iteration 38, loss = 0.03172465
# Iteration 39, loss = 0.02998943
# Iteration 40, loss = 0.03269678
# Iteration 41, loss = 0.03125420
# Iteration 42, loss = 0.03077848
# Iteration 43, loss = 0.03194753
# Iteration 44, loss = 0.02984721
# Iteration 45, loss = 0.02923342
# Iteration 46, loss = 0.02931295
# Iteration 47, loss = 0.02577952
# Iteration 48, loss = 0.03015172
# Iteration 49, loss = 0.02859262
# Iteration 50, loss = 0.02559722
# Iteration 51, loss = 0.02764276
# Iteration 52, loss = 0.02629316
# Iteration 53, loss = 0.02651650
# Iteration 54, loss = 0.02589930
# Iteration 55, loss = 0.02539009
# Iteration 56, loss = 0.02589707
# Iteration 57, loss = 0.02408230
# Iteration 58, loss = 0.02426142
# Iteration 59, loss = 0.02605561
# Iteration 60, loss = 0.02274433
# Acurácia do MLP: 97.52%
# Precisão do modelo: 97.54%
# C:\Users\mpps\AppData\Local\Temp\ipykernel_20196\3666100974.py:217: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Recall do modelo: 97.52%

# %%
### plot the losses
losses = mlp.loss_curve_

plt.plot(losses)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.title("loss behavior per epoch")
plt.show()
plt.rcdefaults()

# %%
cm = confusion_matrix(y_test, predictions)
row_sums = cm.sum(axis=1, keepdims=True)
percentage_matrix = np.round((cm / row_sums) * 100, decimals=1)

sns.set_theme(font_scale=1.2)
heat_map = sns.heatmap(percentage_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel("predictions")
plt.ylabel("data test")
plt.title("classes accuracy")
plt.show()
plt.rcdefaults()
